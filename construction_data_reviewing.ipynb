# %%
import pandas as pd
import streamlit as st
import sodapy as sodapy

from sodapy import Socrata

# %%
all_results = []
offset=0
while True:
    client = Socrata("data.cityofnewyork.us", None)
    results = client.get("w9ak-ipjd", where="filing_date>'2023-12-31T00:00:00.000'", limit=50000,offset=offset)
    offset = offset + 50000
    print(len(results),offset)
    all_results.extend(results)
    if len(results)<50000:
        break
all_results_df = pd.DataFrame.from_dict(all_results)
all_results_df
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
# 50000 50000
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
# 50000 100000
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
# 50000 150000
# 30979 200000
#        job_filing_number                    filing_status    house_no  \
# 0           B00983824-I1                    Permit Issued         203
# 1           M00982779-I1                    Permit Entire         305
# 2           B00983360-S1                         Approved         509
# 3           B00983530-S1                    Permit Entire        1088
# 4           Q00928780-S1                    Permit Entire  167-05 GAR
# ...                  ...                              ...         ...
# 180974      B00808925-P2         Pending SO PE Assignment        1117
# 180975      B01031089-P3              Prof Cert QA Review        1601
# 180976      B01187808-I1      Pending CPE/ACPE Assignment        1522
# 180977      M01187109-I1  Pending Prof Cert QA Assignment         100
# 180978      Q00939603-I1      Pending CPE/ACPE Assignment       36-20
#
#              street_name    borough block   lot      bin commmunity_board  \
# 0           MAPLE STREET   BROOKLYN  5029    57  3114761              309
# 1               7 AVENUE  MANHATTAN   803  7502  1015060              105
# 2           QUENTIN ROAD   BROOKLYN  6637    53  3176104              315
# 3       EAST    8 STREET   BROOKLYN  6528    37  3171163              312
# 4              65 AVENUE     QUEENS  6895     8  4624759              408
# ...                  ...        ...   ...   ...      ...              ...
# 180974     CHURCH AVENUE   BROOKLYN  5072    33  3116376              314
# 180975     DEKALB AVENUE   BROOKLYN  3237    23  3428633              304
# 180976         57 STREET   BROOKLYN  5496    15  3131100              312
# 180977  WEST   89 STREET  MANHATTAN  1219  7501  1032320              107
# 180978         23 AVENUE     QUEENS   819    42  4016208              401
#
#                                             work_on_floor  ...  \
# 0       Basement/Sub-basement, Basement/Sub-basement, ...  ...
# 1                                              Open Space  ...
# 2       Cellar-SO-1582-B00983360-I1, Floor Number(s)-1...  ...
# 3       Cellar-SO-9352-B00983530-I1, Floor Number(s)-1...  ...
# 4                                              Open Space  ...
# ...                                                   ...  ...
# 180974                                                NaN  ...
# 180975                                         Open Space  ...
# 180976      Cellar, Floor Number(s) 001 through 003, Roof  ...
# 180977                    Floor Number(s) 002 through 002  ...
# 180978  Basement/Sub-basement, Floor Number(s) 001 thr...  ...
#
#        temporary_place_of_assembly_work_type_  \
# 0                                          No
# 1                                          No
# 2                                          No
# 3                                          No
# 4                                          No
# ...                                       ...
# 180974                                     No
# 180975                                     No
# 180976                                     No
# 180977                                     No
# 180978                                     No
#
#                                                  job_type  \
# 0                                              Alteration
# 1                                              Alteration
# 2       ALT-CO - New Building with Existing Elements t...
# 3       ALT-CO - New Building with Existing Elements t...
# 4                                            New Building
# ...                                                   ...
# 180974                                      Alteration CO
# 180975                                         Alteration
# 180976                                         Alteration
# 180977                                         Alteration
# 180978                                         Alteration
#
#        built_1_information_value built_2_information_value  \
# 0                            NaN                       NaN
# 1                            NaN                       NaN
# 2                            NaN                       NaN
# 3                            NaN                       NaN
# 4                            NaN                       NaN
# ...                          ...                       ...
# 180974                       NaN                       NaN
# 180975                       NaN                       NaN
# 180976                       NaN                       NaN
# 180977                       NaN                       NaN
# 180978                       NaN                       NaN
#
#        built_2_a_information_value built_2_b_information_value  \
# 0                              NaN                         NaN
# 1                              NaN                         NaN
# 2                              NaN                         NaN
# 3                              NaN                         NaN
# 4                              NaN                         NaN
# ...                            ...                         ...
# 180974                         NaN                         NaN
# 180975                         NaN                         NaN
# 180976                         NaN                         NaN
# 180977                         NaN                         NaN
# 180978                         NaN                         NaN
#
#        filing_representative_middle_initial apt_condo_no_s  \
# 0                                       NaN            NaN
# 1                                       NaN            NaN
# 2                                       NaN            NaN
# 3                                       NaN            NaN
# 4                                       NaN            NaN
# ...                                     ...            ...
# 180974                                  NaN            NaN
# 180975                                  NaN            NaN
# 180976                                  NaN            NaN
# 180977                                  NaN            NaN
# 180978                                  NaN            NaN
#
#        request_legalization includes_permanent_removal
# 0                       NaN                        NaN
# 1                       NaN                        NaN
# 2                       NaN                        NaN
# 3                       NaN                        NaN
# 4                       NaN                        NaN
# ...                     ...                        ...
# 180974                  NaN                        NaN
# 180975                  NaN                        NaN
# 180976                  NaN                        NaN
# 180977                  NaN                        NaN
# 180978                  NaN                        NaN
#
# [180979 rows x 83 columns]

# %%
all_results_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180979 entries, 0 to 180978
# Data columns (total 83 columns):
#  #   Column                                    Non-Null Count   Dtype
# ---  ------                                    --------------   -----
#  0   job_filing_number                         180979 non-null  object
#  1   filing_status                             180979 non-null  object
#  2   house_no                                  180979 non-null  object
#  3   street_name                               180979 non-null  object
#  4   borough                                   180979 non-null  object
#  5   block                                     180979 non-null  object
#  6   lot                                       180979 non-null  object
#  7   bin                                       180979 non-null  object
#  8   commmunity_board                          180678 non-null  object
#  9   work_on_floor                             160505 non-null  object
#  10  applicant_professional_title              180979 non-null  object
#  11  applicant_license                         180979 non-null  object
#  12  applicant_first_name                      180935 non-null  object
#  13  applicants_middle_initial                 56320 non-null   object
#  14  applicant_last_name                       180975 non-null  object
#  15  owner_s_business_name                     170974 non-null  object
#  16  owner_s_street_name                       180825 non-null  object
#  17  city                                      180979 non-null  object
#  18  state                                     180979 non-null  object
#  19  zip                                       180979 non-null  object
#  20  filing_representative_first_name          141801 non-null  object
#  21  filing_representative_last_name           141801 non-null  object
#  22  filing_representative_business_name       141528 non-null  object
#  23  filing_representative_street_name         140138 non-null  object
#  24  filing_representative_city                141546 non-null  object
#  25  filing_representative_state               141546 non-null  object
#  26  filing_representative_zip                 141546 non-null  object
#  27  sprinkler_work_type                       180979 non-null  object
#  28  plumbing_work_type                        180979 non-null  object
#  29  initial_cost                              180979 non-null  object
#  30  total_construction_floor_area             159873 non-null  object
#  31  review_building_code                      179533 non-null  object
#  32  little_e                                  180924 non-null  object
#  33  unmapped_cco_street                       109843 non-null  object
#  34  in_compliance_with_nycecc                 180979 non-null  object
#  35  exempt_from_nycecc                        180979 non-null  object
#  36  building_type                             178205 non-null  object
#  37  existing_stories                          83236 non-null   object
#  38  existing_height                           79004 non-null   object
#  39  existing_dwelling_units                   146974 non-null  object
#  40  proposed_no_of_stories                    92992 non-null   object
#  41  proposed_height                           88751 non-null   object
#  42  proposed_dwelling_units                   157447 non-null  object
#  43  specialinspectionrequirement              126600 non-null  object
#  44  special_inspection_agency_number          107751 non-null  object
#  45  progressinspectionrequirement             109463 non-null  object
#  46  standpipe                                 180979 non-null  object
#  47  antenna                                   180979 non-null  object
#  48  curb_cut                                  180979 non-null  object
#  49  sign                                      180979 non-null  object
#  50  fence                                     180979 non-null  object
#  51  scaffold                                  180979 non-null  object
#  52  shed                                      180979 non-null  object
#  53  postcode                                  156940 non-null  object
#  54  latitude                                  156644 non-null  object
#  55  longitude                                 156644 non-null  object
#  56  council_district                          156644 non-null  object
#  57  census_tract                              156644 non-null  object
#  58  bbl                                       155682 non-null  object
#  59  nta                                       156644 non-null  object
#  60  filing_date                               180979 non-null  object
#  61  current_status_date                       180979 non-null  object
#  62  first_permit_date                         88306 non-null   object
#  63  boiler_equipment_work_type_               180979 non-null  object
#  64  earth_work_work_type_                     180979 non-null  object
#  65  foundation_work_type_                     180979 non-null  object
#  66  general_construction_work_type_           180979 non-null  object
#  67  mechanical_systems_work_type_             180979 non-null  object
#  68  place_of_assembly_work_type_              180979 non-null  object
#  69  protection_mechanical_methods_work_type_  180979 non-null  object
#  70  sidewalk_shed_work_type_                  180979 non-null  object
#  71  structural_work_type_                     180979 non-null  object
#  72  support_of_excavation_work_type_          180979 non-null  object
#  73  temporary_place_of_assembly_work_type_    180979 non-null  object
#  74  job_type                                  180979 non-null  object
#  75  built_1_information_value                 5781 non-null    object
#  76  built_2_information_value                 5781 non-null    object
#  77  built_2_a_information_value               5781 non-null    object
#  78  built_2_b_information_value               5781 non-null    object
#  79  filing_representative_middle_initial      8656 non-null    object
#  80  apt_condo_no_s                            1164 non-null    object
#  81  request_legalization                      4 non-null       object
#  82  includes_permanent_removal                4 non-null       object
# dtypes: object(83)
# memory usage: 114.6+ MB

# %%
trimmed_df = all_results_df[['job_filing_number',
                             'filing_status',
                             'borough',
                             'house_no',
                             'street_name',
                             'initial_cost',
                             'building_type',
                             'existing_stories',
                             'existing_height',
                             'existing_dwelling_units',
                             'proposed_no_of_stories',
                             'proposed_height',
                             'proposed_dwelling_units',
                             'filing_date',
                             'current_status_date',
                             'first_permit_date',
                             'latitude',
                             'longitude',
                             'job_type']]

# %%
trimmed_df
# Out:
#        job_filing_number                    filing_status    borough  \
# 0           B00983824-I1                    Permit Issued   BROOKLYN
# 1           M00982779-I1                    Permit Entire  MANHATTAN
# 2           B00983360-S1                         Approved   BROOKLYN
# 3           B00983530-S1                    Permit Entire   BROOKLYN
# 4           Q00928780-S1                    Permit Entire     QUEENS
# ...                  ...                              ...        ...
# 180974      B00808925-P2         Pending SO PE Assignment   BROOKLYN
# 180975      B01031089-P3              Prof Cert QA Review   BROOKLYN
# 180976      B01187808-I1      Pending CPE/ACPE Assignment   BROOKLYN
# 180977      M01187109-I1  Pending Prof Cert QA Assignment  MANHATTAN
# 180978      Q00939603-I1      Pending CPE/ACPE Assignment     QUEENS
#
#           house_no       street_name initial_cost building_type  \
# 0              203      MAPLE STREET       370000      1 Family
# 1              305          7 AVENUE            1         Other
# 2              509      QUENTIN ROAD        20000      1 Family
# 3             1088  EAST    8 STREET        20000      1 Family
# 4       167-05 GAR         65 AVENUE            0         Other
# ...            ...               ...          ...           ...
# 180974        1117     CHURCH AVENUE       525265         Other
# 180975        1601     DEKALB AVENUE        17000         Other
# 180976        1522         57 STREET        80000      2 Family
# 180977         100  WEST   89 STREET       500000         Other
# 180978       36-20         23 AVENUE        42500         Other
#
#        existing_stories existing_height existing_dwelling_units  \
# 0                     4              35                       1
# 1                   NaN             NaN                      20
# 2                     2              29                       1
# 3                     3              35                       1
# 4                   NaN             NaN                     NaN
# ...                 ...             ...                     ...
# 180974                2              23                       2
# 180975              NaN             NaN                       0
# 180976              NaN             NaN                       0
# 180977                9              85                     108
# 180978              NaN             NaN                       2
#
#        proposed_no_of_stories proposed_height proposed_dwelling_units  \
# 0                           4              35                       1
# 1                         NaN             NaN                      20
# 2                           3              34                       1
# 3                           3              35                       1
# 4                           1              12                       0
# ...                       ...             ...                     ...
# 180974                      2              23                       2
# 180975                    NaN             NaN                       0
# 180976                    NaN             NaN                       2
# 180977                      9              85                     108
# 180978                    NaN             NaN                       5
#
#                     filing_date      current_status_date  \
# 0       2024-01-01T00:00:00.000  2025-02-05T23:39:50.000
# 1       2024-01-01T00:00:00.000  2025-02-28T19:07:01.000
# 2       2024-01-01T00:00:00.000  2025-01-10T15:41:51.000
# 3       2024-01-01T00:00:00.000  2025-02-20T21:00:23.000
# 4       2024-01-01T00:00:00.000  2024-11-12T17:09:58.000
# ...                         ...                      ...
# 180974  2025-03-03T00:00:00.000  2025-03-03T21:02:21.000
# 180975  2025-03-03T00:00:00.000  2025-03-03T15:52:00.000
# 180976  2025-03-03T00:00:00.000  2025-03-03T23:38:20.000
# 180977  2025-03-03T00:00:00.000  2025-03-03T22:08:02.000
# 180978  2025-03-03T00:00:00.000  2025-03-03T21:39:22.000
#
#               first_permit_date   latitude   longitude  \
# 0       2024-11-01T00:00:00.000  40.660608  -73.954319
# 1       2024-01-02T12:17:48.000  40.746707  -73.993735
# 2                           NaN  40.607139  -73.968412
# 3       2025-02-20T00:00:00.000        NaN         NaN
# 4       2024-11-12T00:00:00.000        NaN         NaN
# ...                         ...        ...         ...
# 180974                      NaN   40.64709  -73.969081
# 180975                      NaN        NaN         NaN
# 180976                      NaN  40.627471  -73.991707
# 180977                      NaN  40.787979  -73.971645
# 180978                      NaN  40.772434  -73.910156
#
#                                                  job_type
# 0                                              Alteration
# 1                                              Alteration
# 2       ALT-CO - New Building with Existing Elements t...
# 3       ALT-CO - New Building with Existing Elements t...
# 4                                            New Building
# ...                                                   ...
# 180974                                      Alteration CO
# 180975                                         Alteration
# 180976                                         Alteration
# 180977                                         Alteration
# 180978                                         Alteration
#
# [180979 rows x 19 columns]

# %%
trimmed_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180979 entries, 0 to 180978
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   job_filing_number        180979 non-null  object
#  1   filing_status            180979 non-null  object
#  2   borough                  180979 non-null  object
#  3   house_no                 180979 non-null  object
#  4   street_name              180979 non-null  object
#  5   initial_cost             180979 non-null  object
#  6   building_type            178205 non-null  object
#  7   existing_stories         83236 non-null   object
#  8   existing_height          79004 non-null   object
#  9   existing_dwelling_units  146974 non-null  object
#  10  proposed_no_of_stories   92992 non-null   object
#  11  proposed_height          88751 non-null   object
#  12  proposed_dwelling_units  157447 non-null  object
#  13  filing_date              180979 non-null  object
#  14  current_status_date      180979 non-null  object
#  15  first_permit_date        88306 non-null   object
#  16  latitude                 156644 non-null  object
#  17  longitude                156644 non-null  object
#  18  job_type                 180979 non-null  object
# dtypes: object(19)
# memory usage: 26.2+ MB

# %%
trimmed_df['filing_date'] = pd.to_datetime(trimmed_df['filing_date'],format='mixed')
# Out:
# /var/folders/7b/lhrpdd1j6pd65g1hqvwlmfph0000gn/T/ipykernel_37699/2304866335.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trimmed_df['filing_date'] = pd.to_datetime(trimmed_df['filing_date'],format='mixed')

# %%
trimmed_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180979 entries, 0 to 180978
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   job_filing_number        180979 non-null  object
#  1   filing_status            180979 non-null  object
#  2   borough                  180979 non-null  object
#  3   house_no                 180979 non-null  object
#  4   street_name              180979 non-null  object
#  5   initial_cost             180979 non-null  object
#  6   building_type            178205 non-null  object
#  7   existing_stories         83236 non-null   object
#  8   existing_height          79004 non-null   object
#  9   existing_dwelling_units  146974 non-null  object
#  10  proposed_no_of_stories   92992 non-null   object
#  11  proposed_height          88751 non-null   object
#  12  proposed_dwelling_units  157447 non-null  object
#  13  filing_date              180979 non-null  datetime64[ns]
#  14  current_status_date      180979 non-null  object
#  15  first_permit_date        88306 non-null   object
#  16  latitude                 156644 non-null  object
#  17  longitude                156644 non-null  object
#  18  job_type                 180979 non-null  object
# dtypes: datetime64[ns](1), object(18)
# memory usage: 26.2+ MB

# %%
df_2025 = trimmed_df[trimmed_df['filing_date']>'2024-12-31']

# %%
df_2025
# Out:
#        job_filing_number                    filing_status    borough house_no  \
# 156332      B01061790-S7                       Objections   BROOKLYN      466
# 156333      B01160228-I1                       Objections   BROOKLYN      661
# 156334      X01083719-S1                         Approved      BRONX      297
# 156335      B00881524-P4                         Approved   BROOKLYN      105
# 156336      B01149492-I1             Plan Examiner Review   BROOKLYN      178
# ...                  ...                              ...        ...      ...
# 180974      B00808925-P2         Pending SO PE Assignment   BROOKLYN     1117
# 180975      B01031089-P3              Prof Cert QA Review   BROOKLYN     1601
# 180976      B01187808-I1      Pending CPE/ACPE Assignment   BROOKLYN     1522
# 180977      M01187109-I1  Pending Prof Cert QA Assignment  MANHATTAN      100
# 180978      Q00939603-I1      Pending CPE/ACPE Assignment     QUEENS    36-20
#
#              street_name initial_cost building_type existing_stories  \
# 156332  LAFAYETTE AVENUE            0      3 Family              NaN
# 156333  LINDEN BOULEVARD            0           NaN              NaN
# 156334  EAST  170 STREET         2000         Other              NaN
# 156335    DIAMOND STREET            0         Other              NaN
# 156336    GARFIELD PLACE       344500      2 Family                4
# ...                  ...          ...           ...              ...
# 180974     CHURCH AVENUE       525265         Other                2
# 180975     DEKALB AVENUE        17000         Other              NaN
# 180976         57 STREET        80000      2 Family              NaN
# 180977  WEST   89 STREET       500000         Other                9
# 180978         23 AVENUE        42500         Other              NaN
#
#        existing_height existing_dwelling_units proposed_no_of_stories  \
# 156332             NaN                     NaN                      4
# 156333             NaN                     NaN                    NaN
# 156334             NaN                      70                    NaN
# 156335             NaN                     NaN                      4
# 156336              39                       2                      4
# ...                ...                     ...                    ...
# 180974              23                       2                      2
# 180975             NaN                       0                    NaN
# 180976             NaN                       0                    NaN
# 180977              85                     108                      9
# 180978             NaN                       2                    NaN
#
#        proposed_height proposed_dwelling_units filing_date  \
# 156332              44                       2  2025-01-01
# 156333             NaN                     NaN  2025-01-01
# 156334             NaN                      70  2025-01-01
# 156335              50                       4  2025-01-01
# 156336              39                       2  2025-01-01
# ...                ...                     ...         ...
# 180974              23                       2  2025-03-03
# 180975             NaN                       0  2025-03-03
# 180976             NaN                       2  2025-03-03
# 180977              85                     108  2025-03-03
# 180978             NaN                       5  2025-03-03
#
#             current_status_date first_permit_date   latitude   longitude  \
# 156332  2025-01-07T19:20:12.000               NaN        NaN         NaN
# 156333  2025-02-04T21:03:01.000               NaN  40.653599   -73.93403
# 156334  2025-01-02T16:57:04.000               NaN  40.837734  -73.910472
# 156335  2025-02-28T21:59:44.000               NaN        NaN         NaN
# 156336  2025-03-03T20:00:44.000               NaN  40.672794  -73.978056
# ...                         ...               ...        ...         ...
# 180974  2025-03-03T21:02:21.000               NaN   40.64709  -73.969081
# 180975  2025-03-03T15:52:00.000               NaN        NaN         NaN
# 180976  2025-03-03T23:38:20.000               NaN  40.627471  -73.991707
# 180977  2025-03-03T22:08:02.000               NaN  40.787979  -73.971645
# 180978  2025-03-03T21:39:22.000               NaN  40.772434  -73.910156
#
#              job_type
# 156332   New Building
# 156333        No Work
# 156334     Alteration
# 156335   New Building
# 156336     Alteration
# ...               ...
# 180974  Alteration CO
# 180975     Alteration
# 180976     Alteration
# 180977     Alteration
# 180978     Alteration
#
# [24647 rows x 19 columns]

# %%
df_2025.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 24647 entries, 156332 to 180978
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   job_filing_number        24647 non-null  object
#  1   filing_status            24647 non-null  object
#  2   borough                  24647 non-null  object
#  3   house_no                 24647 non-null  object
#  4   street_name              24647 non-null  object
#  5   initial_cost             24647 non-null  object
#  6   building_type            24369 non-null  object
#  7   existing_stories         12279 non-null  object
#  8   existing_height          11693 non-null  object
#  9   existing_dwelling_units  20256 non-null  object
#  10  proposed_no_of_stories   13637 non-null  object
#  11  proposed_height          13048 non-null  object
#  12  proposed_dwelling_units  21631 non-null  object
#  13  filing_date              24647 non-null  datetime64[ns]
#  14  current_status_date      24647 non-null  object
#  15  first_permit_date        6870 non-null   object
#  16  latitude                 21781 non-null  object
#  17  longitude                21781 non-null  object
#  18  job_type                 24647 non-null  object
# dtypes: datetime64[ns](1), object(18)
# memory usage: 3.8+ MB

# %%
from pages.Construction_Application import remove_blanks

# %%
no_blanks_2025 = remove_blanks(df_2025,['proposed_dwelling_units','existing_dwelling_units'])

# %%
no_blanks_2025['proposed_dwelling_units'] = no_blanks_2025['proposed_dwelling_units'].astype(int)
# Out:
# /var/folders/7b/lhrpdd1j6pd65g1hqvwlmfph0000gn/T/ipykernel_37699/4173096539.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no_blanks_2025['proposed_dwelling_units'] = no_blanks_2025['proposed_dwelling_units'].astype(int)

# %%
no_blanks_2025['existing_dwelling_units'] = no_blanks_2025['existing_dwelling_units'].astype(int)
# Out:
# /var/folders/7b/lhrpdd1j6pd65g1hqvwlmfph0000gn/T/ipykernel_37699/1617907478.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no_blanks_2025['existing_dwelling_units'] = no_blanks_2025['existing_dwelling_units'].astype(int)

# %%
no_blanks_2025['change_in_units'] = no_blanks_2025['proposed_dwelling_units'] - no_blanks_2025['existing_dwelling_units']
# Out:
# /var/folders/7b/lhrpdd1j6pd65g1hqvwlmfph0000gn/T/ipykernel_37699/4007570245.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no_blanks_2025['change_in_units'] = no_blanks_2025['proposed_dwelling_units'] - no_blanks_2025['existing_dwelling_units']

# %%
no_blanks_2025
# Out:
#        job_filing_number                    filing_status    borough house_no  \
# 156334      X01083719-S1                         Approved      BRONX      297
# 156336      B01149492-I1             Plan Examiner Review   BROOKLYN      178
# 156339      M01087604-S3                         Approved  MANHATTAN       68
# 156340      M01139243-I1                    Permit Entire  MANHATTAN      205
# 156341      B01159609-P1                         Approved   BROOKLYN      23A
# ...                  ...                              ...        ...      ...
# 180974      B00808925-P2         Pending SO PE Assignment   BROOKLYN     1117
# 180975      B01031089-P3              Prof Cert QA Review   BROOKLYN     1601
# 180976      B01187808-I1      Pending CPE/ACPE Assignment   BROOKLYN     1522
# 180977      M01187109-I1  Pending Prof Cert QA Assignment  MANHATTAN      100
# 180978      Q00939603-I1      Pending CPE/ACPE Assignment     QUEENS    36-20
#
#              street_name initial_cost building_type existing_stories  \
# 156334  EAST  170 STREET         2000         Other              NaN
# 156336    GARFIELD PLACE       344500      2 Family                4
# 156339     LAIGHT STREET        15000         Other              NaN
# 156340  WEST   14 STREET        33000         Other                5
# 156341     VERNON AVENUE         4000      3 Family              NaN
# ...                  ...          ...           ...              ...
# 180974     CHURCH AVENUE       525265         Other                2
# 180975     DEKALB AVENUE        17000         Other              NaN
# 180976         57 STREET        80000      2 Family              NaN
# 180977  WEST   89 STREET       500000         Other                9
# 180978         23 AVENUE        42500         Other              NaN
#
#        existing_height  existing_dwelling_units proposed_no_of_stories  \
# 156334             NaN                       70                    NaN
# 156336              39                        2                      4
# 156339             NaN                       10                    NaN
# 156340              50                        4                      5
# 156341             NaN                        3                    NaN
# ...                ...                      ...                    ...
# 180974              23                        2                      2
# 180975             NaN                        0                    NaN
# 180976             NaN                        0                    NaN
# 180977              85                      108                      9
# 180978             NaN                        2                    NaN
#
#        proposed_height  proposed_dwelling_units filing_date  \
# 156334             NaN                       70  2025-01-01
# 156336              39                        2  2025-01-01
# 156339             NaN                       10  2025-01-01
# 156340              50                        4  2025-01-01
# 156341             NaN                        3  2025-01-01
# ...                ...                      ...         ...
# 180974              23                        2  2025-03-03
# 180975             NaN                        0  2025-03-03
# 180976             NaN                        2  2025-03-03
# 180977              85                      108  2025-03-03
# 180978             NaN                        5  2025-03-03
#
#             current_status_date        first_permit_date   latitude  \
# 156334  2025-01-02T16:57:04.000                      NaN  40.837734
# 156336  2025-03-03T20:00:44.000                      NaN  40.672794
# 156339  2025-02-25T19:57:09.000                      NaN  40.722141
# 156340  2025-01-30T13:38:05.000  2025-01-30T00:00:00.000  40.738775
# 156341  2025-01-02T21:05:42.000                      NaN  40.694412
# ...                         ...                      ...        ...
# 180974  2025-03-03T21:02:21.000                      NaN   40.64709
# 180975  2025-03-03T15:52:00.000                      NaN        NaN
# 180976  2025-03-03T23:38:20.000                      NaN  40.627471
# 180977  2025-03-03T22:08:02.000                      NaN  40.787979
# 180978  2025-03-03T21:39:22.000                      NaN  40.772434
#
#          longitude       job_type  change_in_units
# 156334  -73.910472     Alteration                0
# 156336  -73.978056     Alteration                0
# 156339  -74.009885     Alteration                0
# 156340  -74.000184     Alteration                0
# 156341  -73.951129     Alteration                0
# ...            ...            ...              ...
# 180974  -73.969081  Alteration CO                0
# 180975         NaN     Alteration                0
# 180976  -73.991707     Alteration                2
# 180977  -73.971645     Alteration                0
# 180978  -73.910156     Alteration                3
#
# [19868 rows x 20 columns]

# %%
sum_new_units_2025 = no_blanks_2025['change_in_units'].sum()

# %%
sum_new_units_2025
# Out:
# np.int64(44191)

# %%
no_blanks_2025['filing_status'].unique()
# Out:
# array(['Approved', 'Plan Examiner Review', 'Permit Entire', 'Objections',
#        'LOC Issued', 'Filing Withdrawn', 'Permit Issued', 'Incomplete',
#        'QA Failed', 'OnHold-NoGoodCheck', 'SO Plan Examiner Review',
#        'Chief Plan Examiner/ Assistant Chief Plan Examiner Review',
#        'Prof Cert QA Review', 'Pending Plan Examiner Assignment',
#        'On Hold – Administrative Action', 'Disapproved',
#        'On Hold - Pending Supersede of Applicant of Record',
#        'LL 158-2017-Denied', 'Pending CPE/ACPE Assignment',
#        'Zoning Plan Examiner Review', 'Pending SO PE Assignment',
#        'Pending Prof Cert QA Assignment',
#        'Pending Zoning Plan Examiner Assignment'], dtype=object)

# %%
approved_2025 = no_blanks_2025[no_blanks_2025['filing_status'].isin(['Approved','Permit Entire','LOC Issued','Permit Issued'])]

# %%
approved_2025
# Out:
#        job_filing_number  filing_status    borough house_no       street_name  \
# 156334      X01083719-S1       Approved      BRONX      297  EAST  170 STREET
# 156339      M01087604-S3       Approved  MANHATTAN       68     LAIGHT STREET
# 156340      M01139243-I1  Permit Entire  MANHATTAN      205  WEST   14 STREET
# 156341      B01159609-P1       Approved   BROOKLYN      23A     VERNON AVENUE
# 156343      M01142743-S1  Permit Entire  MANHATTAN       55  EAST   52 STREET
# ...                  ...            ...        ...      ...               ...
# 180868      M01188957-I1  Permit Entire  MANHATTAN      724      FIFTH AVENUE
# 180883      B01072009-P2       Approved   BROOKLYN      171     CALYER STREET
# 180888      M01188305-I1       Approved  MANHATTAN      753          9 AVENUE
# 180894      B01187027-I1       Approved   BROOKLYN      594  VAN BUREN STREET
# 180950      B01169561-I1  Permit Entire   BROOKLYN      884   HERKIMER STREET
#
#        initial_cost building_type existing_stories existing_height  \
# 156334         2000         Other              NaN             NaN
# 156339        15000         Other              NaN             NaN
# 156340        33000         Other                5              50
# 156341         4000      3 Family              NaN             NaN
# 156343       110000         Other               42             575
# ...             ...           ...              ...             ...
# 180868         1000         Other              NaN             NaN
# 180883         2000         Other              NaN             NaN
# 180888       196920         Other                5              55
# 180894        92755      2 Family                3              27
# 180950         1000      2 Family              NaN             NaN
#
#         existing_dwelling_units proposed_no_of_stories proposed_height  \
# 156334                       70                    NaN             NaN
# 156339                       10                    NaN             NaN
# 156340                        4                      5              50
# 156341                        3                    NaN             NaN
# 156343                        0                     42             575
# ...                         ...                    ...             ...
# 180868                        0                    NaN             NaN
# 180883                       21                    NaN             NaN
# 180888                       12                      5              55
# 180894                        2                      3              27
# 180950                        2                    NaN             NaN
#
#         proposed_dwelling_units filing_date      current_status_date  \
# 156334                       70  2025-01-01  2025-01-02T16:57:04.000
# 156339                       10  2025-01-01  2025-02-25T19:57:09.000
# 156340                        4  2025-01-01  2025-01-30T13:38:05.000
# 156341                        3  2025-01-01  2025-01-02T21:05:42.000
# 156343                        0  2025-01-01  2025-01-10T16:04:43.000
# ...                         ...         ...                      ...
# 180868                        0  2025-03-03  2025-03-03T19:27:00.000
# 180883                       21  2025-03-03  2025-03-03T21:08:16.000
# 180888                       12  2025-03-03  2025-03-03T19:12:12.000
# 180894                        2  2025-03-03  2025-03-03T19:26:00.000
# 180950                        2  2025-03-03  2025-03-03T19:22:29.000
#
#               first_permit_date   latitude   longitude    job_type  \
# 156334                      NaN  40.837734  -73.910472  Alteration
# 156339                      NaN  40.722141  -74.009885  Alteration
# 156340  2025-01-30T00:00:00.000  40.738775  -74.000184  Alteration
# 156341                      NaN  40.694412  -73.951129  Alteration
# 156343  2025-01-10T00:00:00.000  40.758828  -73.973978  Alteration
# ...                         ...        ...         ...         ...
# 180868  2025-03-03T14:27:00.000  40.762495  -73.974323  Alteration
# 180883                      NaN        NaN         NaN  Alteration
# 180888                      NaN   40.76391  -73.988654  Alteration
# 180894                      NaN  40.692477  -73.925762  Alteration
# 180950  2025-03-03T14:22:23.000  40.678241  -73.924167  Alteration
#
#         change_in_units
# 156334                0
# 156339                0
# 156340                0
# 156341                0
# 156343                0
# ...                 ...
# 180868                0
# 180883                0
# 180888                0
# 180894                0
# 180950                0
#
# [14904 rows x 20 columns]

# %%
approved_2025.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 14904 entries, 156334 to 180950
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   job_filing_number        14904 non-null  object
#  1   filing_status            14904 non-null  object
#  2   borough                  14904 non-null  object
#  3   house_no                 14904 non-null  object
#  4   street_name              14904 non-null  object
#  5   initial_cost             14904 non-null  object
#  6   building_type            14904 non-null  object
#  7   existing_stories         8224 non-null   object
#  8   existing_height          7799 non-null   object
#  9   existing_dwelling_units  14904 non-null  int64
#  10  proposed_no_of_stories   8220 non-null   object
#  11  proposed_height          7797 non-null   object
#  12  proposed_dwelling_units  14904 non-null  int64
#  13  filing_date              14904 non-null  datetime64[ns]
#  14  current_status_date      14904 non-null  object
#  15  first_permit_date        5238 non-null   object
#  16  latitude                 13657 non-null  object
#  17  longitude                13657 non-null  object
#  18  job_type                 14904 non-null  object
#  19  change_in_units          14904 non-null  int64
# dtypes: datetime64[ns](1), int64(3), object(16)
# memory usage: 2.4+ MB

# %%
sum_approved_new_units_2025 = approved_2025['change_in_units'].sum()
sum_approved_new_units_2025
# Out:
# np.int64(35147)

# %%
number_of_approved2025 = len(approved_2025)
number_of_approved2025
# Out:
# 14904

# %%
number_of_applications_2025 = len(df_2025)
number_of_applications_2025
# Out:
# 24647

# %%
from construction_functions import connect_to_nyc_data
connect_to_nyc_data("ic3t-wcy2","job_status='R'")
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
# 20000 20000
# 20000 40000
#            job__ doc__   borough house__       street_name  block    lot  \
# 0      302163557    01  BROOKLYN      96    ROCKWELL PLACE  02106  07501
# 1      301773631    01  BROOKLYN     591   FLATBUSH AVENUE  05034  00004
# 2      421789559    01    QUEENS   98-87       QUEENS BLVD  02105  00001
# 3      240304167    01     BRONX     101       LINCOLN AVE  02316  00001
# 4      440707709    01    QUEENS  131-24        223 STREET  12932  00108
# ...          ...   ...       ...     ...               ...    ...    ...
# 39995  401740167    01    QUEENS   64-11         99 STREET  02113  00001
# 39996  401345852    01    QUEENS  167-02       45TH AVENUE  05446  00018
# 39997  401740559    01    QUEENS  121-57        233 STREET  12860  00016
# 39998  401740700    01    QUEENS  149-18        118 STREET  11818  00047
# 39999  401243365    01    QUEENS   93-20  ROOSEVELT AVENUE  01562  00025
#
#          bin__ job_type job_status  ... curb_cut fuel_storage standpipe  \
# 0      3059160       A1          R  ...      NaN          NaN       NaN
# 1      3115047       A1          R  ...      NaN          NaN       NaN
# 2      4050525       DM          R  ...      NaN          NaN       NaN
# 3      2130735       A3          R  ...      NaN          NaN       NaN
# 4      4278532       A2          R  ...      NaN          NaN       NaN
# ...        ...      ...        ...  ...      ...          ...       ...
# 39995  4050798       A2          R  ...      NaN          NaN       NaN
# 39996  4123454       PA          R  ...      NaN          NaN       NaN
# 39997  4276751       A2          R  ...      NaN          NaN       NaN
# 39998  4256890       NB          R  ...        X          NaN       NaN
# 39999  4039040       DM          R  ...      NaN          NaN       NaN
#
#       zoning_dist3 owner_s_house_number owner_shouse_street_name city_ state  \
# 0              NaN                  NaN                      NaN   NaN   NaN
# 1              NaN                  NaN                      NaN   NaN   NaN
# 2              NaN                  NaN                      NaN   NaN   NaN
# 3              NaN                  NaN                      NaN   NaN   NaN
# 4              NaN                  NaN                      NaN   NaN   NaN
# ...            ...                  ...                      ...   ...   ...
# 39995          NaN                  NaN                      NaN   NaN   NaN
# 39996          NaN                  NaN                      NaN   NaN   NaN
# 39997          NaN                  NaN                      NaN   NaN   NaN
# 39998          NaN                  NaN                      NaN   NaN   NaN
# 39999          NaN                  NaN                      NaN   NaN   NaN
#
#        zip signoff_date
# 0      NaN          NaN
# 1      NaN          NaN
# 2      NaN          NaN
# 3      NaN          NaN
# 4      NaN          NaN
# ...    ...          ...
# 39995  NaN          NaN
# 39996  NaN          NaN
# 39997  NaN          NaN
# 39998  NaN          NaN
# 39999  NaN          NaN
#
# [40000 rows x 96 columns]

# %%
df_2025['job_type'].unique()
# Out:
# array(['New Building', 'No Work', 'Alteration', 'Alteration CO',
#        'ALT-CO - New Building with Existing Elements to Remain',
#        'Full Demolition'], dtype=object)
