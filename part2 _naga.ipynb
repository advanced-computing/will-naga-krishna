# %% [markdown]
# # Construction Job Applications Data:

# %%
import pandas as pd
from sodapy import Socrata

client = Socrata("data.cityofnewyork.us", None)
df_list = []
offset = 0

while len(df_list)<10000:
    results = client.get("ic3t-wcy2", 
                         limit=2000,
                         offset=offset)
    offset += 2000
    df_list.extend(results)

df = pd.DataFrame.from_records(df_list)
df[['job_type', 'gis_census_tract', 'gis_latitude', 'gis_longitude']]
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
#      job_type gis_census_tract gis_latitude gis_longitude
# 0          A1              133    40.676829    -73.981570
# 1          A2              153    40.668861    -73.982156
# 2          A2              519    40.717318    -73.955431
# 3          A1              114    40.638728    -74.001250
# 4          A1               33    40.687317    -73.979159
# ...       ...              ...          ...           ...
# 9995       A3              534    40.621819    -73.961690
# 9996       A2             1070    40.649969    -73.870669
# 9997       A2               77    40.678453    -73.991686
# 9998       A3               41    40.686398    -73.982783
# 9999       A2              153    40.668293    -73.979237
#
# [10000 rows x 4 columns]

# %%
import plotnine as p9

plot = (
    p9.ggplot(df)
    + p9.aes(x='job_type')
    + p9.geom_bar()
    + p9.labs(title='Job Type Distribution')
)

plot

# %%
df.info()

# %%
import pandas as pd
from sodapy import Socrata

client = Socrata("data.cityofnewyork.us", None)
df_list = []
offset = 0

while len(df_list)<10000:
    results = client.get("w2pb-icbu", 
                         limit=2000,
                         offset=offset)
    offset += 2000
    df_list.extend(results)

df_land = pd.DataFrame.from_records(df_list)

df_land[['sale_price', 'borough', 'latitude', 'longitude']]
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
#         sale_price borough   latitude   longitude
# 0      43300000.00       1  40.749704   -74.00493
# 1     148254147.00       1  40.749364  -74.004132
# 2      11000000.00       1  40.752067  -74.002931
# 3     591800000.00       1        NaN         NaN
# 4             0.00       1  40.745809  -73.999729
# ...            ...     ...        ...         ...
# 9995    1475000.00       1  40.765777  -73.963174
# 9996     737000.00       1  40.765777  -73.963174
# 9997     799900.00       1  40.765777  -73.963174
# 9998    2270000.00       1  40.766276  -73.962279
# 9999    1210000.00       1  40.766276  -73.962279
#
# [10000 rows x 4 columns]

# %%
import plotly.express as px

plot_land = px.line(
    df_land,
    x='sale_price',
    title='Sale Price Distribution',
)

plot_land

# %%
df_land.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 28 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   borough                     10000 non-null  object
#  1   neighborhood                10000 non-null  object
#  2   building_class_category     10000 non-null  object
#  3   tax_class_as_of_final_roll  9808 non-null   object
#  4   block                       10000 non-null  object
#  5   lot                         10000 non-null  object
#  6   building_class_as_of_final  9808 non-null   object
#  7   address                     10000 non-null  object
#  8   zip_code                    10000 non-null  object
#  9   residential_units           6230 non-null   object
#  10  commercial_units            6230 non-null   object
#  11  total_units                 6230 non-null   object
#  12  land_square_feet            6230 non-null   object
# ...
