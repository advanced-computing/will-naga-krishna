# %%
import pandas as pd
import streamlit as st

# %% [markdown]
# # Construction Permits Data (not used):

# %%
#!/usr/bin/env python

# make sure to install these packages before running:
# pip install pandas
! pip install sodapy

from sodapy import Socrata

# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("data.cityofnewyork.us", None)

# Example authenticated client (needed for non-public datasets):
# client = Socrata(data.cityofnewyork.us,
#                  MyAppToken,
#                  username="user@example.com",
#                  password="AFakePassword")

# client.timeout = 60

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("ipu4-2q9a", limit=2000)

# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)
# Out:
# Collecting sodapy
#   Using cached sodapy-2.2.0-py2.py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: requests>=2.28.1 in ./.venv/lib/python3.12/site-packages (from sodapy) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.12/site-packages (from requests>=2.28.1->sodapy) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.12/site-packages (from requests>=2.28.1->sodapy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.12/site-packages (from requests>=2.28.1->sodapy) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.12/site-packages (from requests>=2.28.1->sodapy) (2025.1.31)
# Using cached sodapy-2.2.0-py2.py3-none-any.whl (15 kB)
# Installing collected packages: sodapy
# Successfully installed sodapy-2.2.0
#
# [notice] A new release of pip is available: 24.0 -> 25.0
# [notice] To update, run: pip install --upgrade pip
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
results_df
# Out:
#             borough    bin__ house__       street_name      job__ job_doc___  \
# 0         MANHATTAN  1088749       1       MADISON AVE  141008987         01
# 1     STATEN ISLAND  5076937      87     BOYLAN STREET  540218539         01
# 2     STATEN ISLAND  5001506     217  LAFAYETTE AVENUE  540218575         01
# 3     STATEN ISLAND  5067021     170    OAKDALE STREET  540218600         01
# 4     STATEN ISLAND  5058036     273         10 STREET  540218628         01
# ...             ...      ...     ...               ...        ...        ...
# 1995         QUEENS  4271695  118-29      194TH STREET  440715807         01
# 1996      MANHATTAN  1018263     155  EAST 29TH STREET  123410923         01
# 1997         QUEENS  4146256   59-37          155TH ST  440727037         01
# 1998         QUEENS  4270698  168-09        140 AVENUE  440726948         01
# 1999       BROOKLYN  3084215     404     MILLER AVENUE  340839739         01
#
#      job_type self_cert  block    lot  ... city state owner_s_zip_code  \
# 0          A3         Y  00853  00002  ...  NaN   NaN              NaN
# 1          A2         Y  05687  00066  ...  NaN   NaN              NaN
# 2          A2         Y  00064  00022  ...  NaN   NaN              NaN
# 3          A2         Y  05260  00001  ...  NaN   NaN              NaN
# 4          A2         Y  04242  00045  ...  NaN   NaN              NaN
# ...       ...       ...    ...    ...  ...  ...   ...              ...
# 1995       A2         Y  12615  00047  ...  NaN   NaN              NaN
# 1996       A2         Y  00885  00042  ...  NaN   NaN              NaN
# 1997       A2         Y  06733  00016  ...  NaN   NaN              NaN
# 1998       A2         Y  12574  00006  ...  NaN   NaN              NaN
# 1999       A2         N  03759  00030  ...  NaN   NaN              NaN
#
#      site_safety_mgr_s_first_name site_safety_mgr_s_last_name  \
# 0                             NaN                         NaN
# 1                             NaN                         NaN
# 2                             NaN                         NaN
# 3                             NaN                         NaN
# 4                             NaN                         NaN
# ...                           ...                         ...
# 1995                          NaN                         NaN
# 1996                          NaN                         NaN
# 1997                          NaN                         NaN
# 1998                          NaN                         NaN
# 1999                          NaN                         NaN
#
#      site_safety_mgr_business_name hic_license act_as_superintendent  \
# 0                              NaN         NaN                   NaN
# 1                              NaN         NaN                   NaN
# 2                              NaN         NaN                   NaN
# 3                              NaN         NaN                   NaN
# 4                              NaN         NaN                   NaN
# ...                            ...         ...                   ...
# 1995                           NaN         NaN                   NaN
# 1996                           NaN         NaN                   NaN
# 1997                           NaN         NaN                   NaN
# 1998                           NaN         NaN                   NaN
# 1999                           NaN         NaN                   NaN
#
#      permittee_s_other_title oil_gas
# 0                        NaN     NaN
# 1                        NaN     NaN
# 2                        NaN     NaN
# 3                        NaN     NaN
# 4                        NaN     NaN
# ...                      ...     ...
# 1995                     NaN     NaN
# 1996                     NaN     NaN
# 1997                     NaN     NaN
# 1998                     NaN     NaN
# 1999                     NaN     NaN
#
# [2000 rows x 59 columns]

# %%
trimmed_df = results_df[['issuance_date','community_board','job_type','bldg_type','residential',]]

# %%
trimmed_df
# Out:
#      issuance_date community_board job_type bldg_type residential
# 0       05/10/2022             105       A3         2         NaN
# 1       05/10/2022             503       A2         1         YES
# 2       05/10/2022             501       A2         1         YES
# 3       05/10/2022             503       A2         1         YES
# 4       05/10/2022             502       A2         1         YES
# ...            ...             ...      ...       ...         ...
# 1995    05/19/2022             412       A2         1         YES
# 1996    05/19/2022             106       A2         2         YES
# 1997    05/19/2022             407       A2         1         YES
# 1998    05/19/2022             412       A2         1         YES
# 1999    05/19/2022             305       A2         1         YES
#
# [2000 rows x 5 columns]

# %% [markdown]
# # Construction Job Applications Data:

# %%
# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("data.cityofnewyork.us", None)

# Example authenticated client (needed for non-public datasets):
# client = Socrata(data.cityofnewyork.us,
#                  MyAppToken,
#                  username="user@example.com",
#                  password="AFakePassword")

# client.timeout = 60

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("ic3t-wcy2", limit=2000)

# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
results_df
# Out:
#           job__ doc__        borough house__        street_name  block    lot  \
# 0     321386512    01       BROOKLYN     666           UNION ST  00955  00031
# 1     301773613    01       BROOKLYN     412           7 STREET  01000  00017
# 2     301776077    01       BROOKLYN     208  NORTH    8 STREET  02321  00008
# 3     301776291    01       BROOKLYN     933          51 STREET  05645  00066
# 4     302163557    01       BROOKLYN      96     ROCKWELL PLACE  02106  07501
# ...         ...   ...            ...     ...                ...    ...    ...
# 1995  301775201    01       BROOKLYN    1629          46 STREET  05434  00074
# 1996  540239632    01  STATEN ISLAND     122      TAYLOR STREET  00199  00071
# 1997  500876867    02  STATEN ISLAND     130    LINDENWOOD ROAD  05245  00001
# 1998  302073645    01       BROOKLYN    4205       QUENTIN ROAD  07866  00008
# 1999  302074546    01       BROOKLYN      60       TURNER PLACE  05113  00001
#
#         bin__ job_type job_status  ... sprinkler zoning_dist3 city_owned  \
# 0     3020058       A1          X  ...       NaN          NaN        NaN
# 1     3021944       A2          P  ...       NaN          NaN        NaN
# 2     3061967       A2          X  ...       NaN          NaN        NaN
# 3     3137917       A1          X  ...       NaN          NaN        NaN
# 4     3059160       A1          R  ...       NaN          NaN        NaN
# ...       ...      ...        ...  ...       ...          ...        ...
# 1995  3128509       DM          X  ...       NaN          NaN        NaN
# 1996  5175946       A3          X  ...       NaN          NaN        NaN
# 1997  5175089       A2          P  ...       NaN          NaN          Y
# 1998  3219540       A2          X  ...       NaN          NaN        NaN
# 1999  3117427       A2          X  ...       NaN          NaN        NaN
#
#      horizontal_enlrgmt fire_alarm boiler fuel_burning curb_cut standpipe  \
# 0                   NaN        NaN    NaN          NaN      NaN       NaN
# 1                   NaN        NaN    NaN          NaN      NaN       NaN
# 2                   NaN        NaN    NaN          NaN      NaN       NaN
# 3                   NaN        NaN    NaN          NaN      NaN       NaN
# 4                   NaN        NaN    NaN          NaN      NaN       NaN
# ...                 ...        ...    ...          ...      ...       ...
# 1995                NaN        NaN    NaN          NaN      NaN       NaN
# 1996                NaN        NaN    NaN          NaN      NaN       NaN
# 1997                NaN        NaN    NaN          NaN      NaN       NaN
# 1998                NaN        NaN    NaN          NaN      NaN       NaN
# 1999                NaN        NaN    NaN          NaN      NaN       NaN
#
#      fuel_storage
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 1995          NaN
# 1996          NaN
# 1997          NaN
# 1998          NaN
# 1999          NaN
#
# [2000 rows x 91 columns]

# %%
st.map(results_df, latitude='gis_latitude', longitude='gis_longitude')
# Out:
# ---------------------------------------------------------------------------
# StreamlitAPIException                     Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 st.map(results_df, latitude='gis_latitude', longitude='gis_longitude')
#
# File ~/Documents/Advanced_Computing/project_repo/willnaga/.venv/lib/python3.12/site-packages/streamlit/runtime/metrics_util.py:410, in gather_metrics.<locals>.wrapped_func(*args, **kwargs)
#     408         _LOGGER.debug("Failed to collect command telemetry", exc_info=ex)
#     409 try:
# --> 410     result = non_optional_func(*args, **kwargs)
#     411 except RerunException as ex:
#     412     # Duplicated from below, because static analysis tools get confused
#     413     # by deferring the rethrow.
#     414     if tracking_activated and command_telemetry:
#
# File ~/Documents/Advanced_Computing/project_repo/willnaga/.venv/lib/python3.12/site-packages/streamlit/elements/map.py:242, in MapMixin.map(self, data, latitude, longitude, color, size, zoom, use_container_width, width, height)
#     240 map_style = None
#     241 map_proto = DeckGlJsonChartProto()
# --> 242 deck_gl_json = to_deckgl_json(
#     243     data, latitude, longitude, size, color, map_style, zoom
#     244 )
#     245 marshall(
#     246     map_proto, deck_gl_json, use_container_width, width=width, height=height
#     247 )
#     248 return self.dg._enqueue("deck_gl_json_chart", map_proto)
#
# File ~/Documents/Advanced_Computing/project_repo/willnaga/.venv/lib/python3.12/site-packages/streamlit/elements/map.py:276, in to_deckgl_json(data, lat, lon, size, color, map_style, zoom)
#     272     return json.dumps(_DEFAULT_MAP)
#     274 df = dataframe_util.convert_anything_to_pandas_df(data)
# --> 276 lat_col_name = _get_lat_or_lon_col_name(df, "latitude", lat, _DEFAULT_LAT_COL_NAMES)
#     277 lon_col_name = _get_lat_or_lon_col_name(
#     278     df, "longitude", lon, _DEFAULT_LON_COL_NAMES
#     279 )
#     280 size_arg, size_col_name = _get_value_and_col_name(df, size, _DEFAULT_SIZE)
#
# File ~/Documents/Advanced_Computing/project_repo/willnaga/.venv/lib/python3.12/site-packages/streamlit/elements/map.py:365, in _get_lat_or_lon_col_name(data, human_readable_name, col_name_from_user, default_col_names)
#     358 # Check that the column is well-formed.
#     359 # IMPLEMENTATION NOTE: We can't use isnull().values.any() because .values can return
#     360 # ExtensionArrays, which don't have a .any() method.
#     361 # (Read about ExtensionArrays here: # https://pandas.pydata.org/community/blog/extension-arrays.html)
#     362 # However, after a performance test I found the solution below runs basically as
#     363 # fast as .values.any().
#     364 if any(data[col_name].isnull().array):
# --> 365     raise StreamlitAPIException(
#     366         f"Column {col_name} is not allowed to contain null values, such "
#     367         "as NaN, NaT, or None."
#     368     )
#     370 return col_name
#
# StreamlitAPIException: Column gis_latitude is not allowed to contain null values, such as NaN, NaT, or None.
